# %% [markdown]
# # Install CAMEL from source

# %%
! git clone https://github.com/lightaime/camel.git
# %cd camel/
! pip install -e .
# Out:
# Cloning into 'camel'...
# remote: Enumerating objects: 783, done.
# remote: Counting objects: 100% (458/458), done.
# remote: Compressing objects: 100% (257/257), done.
# remote: Total 783 (delta 272), reused 321 (delta 192), pack-reused 325
# Receiving objects: 100% (783/783), 1.00 MiB | 21.87 MiB/s, done.
# Resolving deltas: 100% (410/410), done.
# /content/camel/camel/camel
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/camel/camel/camel
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from camel==0.0.1) (1.22.4)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.10/dist-packages (from camel==0.0.1) (0.3.3)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.10/dist-packages (from camel==0.0.1) (8.2.2)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from camel==0.0.1) (0.4.6)
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (from camel==0.0.1) (0.27.5)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai->camel==0.0.1) (3.8.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai->camel==0.0.1) (4.65.0)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai->camel==0.0.1) (2.27.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken->camel==0.0.1) (2022.10.31)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai->camel==0.0.1) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai->camel==0.0.1) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai->camel==0.0.1) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai->camel==0.0.1) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai->camel==0.0.1) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai->camel==0.0.1) (1.9.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai->camel==0.0.1) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai->camel==0.0.1) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai->camel==0.0.1) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai->camel==0.0.1) (4.0.2)
# Building wheels for collected packages: camel
#   Building editable for camel (pyproject.toml) ... done
#   Created wheel for camel: filename=camel-0.0.1-0.editable-py3-none-any.whl size=9585 sha256=441458040d92c47e6b2c0b5f562ba6788ea934d31950c6e3ae71fa7a398daa36
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6mdx52xb/wheels/4c/5f/f8/a8942eaefbb8f61640923683150fdaddbcde7bf6dba5d473dc
# Successfully built camel
# Installing collected packages: camel
#   Attempting uninstall: camel
#     Found existing installation: camel 0.0.1
#     Uninstalling camel-0.0.1:
#       Successfully uninstalled camel-0.0.1
# Successfully installed camel-0.0.1

# %% [markdown]
# # Run CAMEL role-playing session

# %%
import os
import openai

openai.api_key = "sk-..."

# %%
import time
from colorama import Fore
def print_text_animated(text):
    for char in text:
        print(char, end="", flush=True)
        time.sleep(0.02)

# %%
from camel.agents import RolePlaying
  
task_prompt = "Design a custom game using pygame"
print(Fore.YELLOW + f"Original task prompt:\n{task_prompt}\n")
role_play_session = RolePlaying("Computer Programmer", "Gamer", task_prompt)
print(Fore.CYAN + f"Specified task prompt:\n{role_play_session.task_prompt}\n")

chat_turn_limit, n = 10, 0
assistant_msg, _ = role_play_session.init_chat()
while n < chat_turn_limit:
    n += 1
    (assistant_msg, _, _), (user_msg, _, _) = role_play_session.step(assistant_msg)
    print_text_animated(Fore.BLUE + f"AI User:\n\n{user_msg.content}\n\n")
    print_text_animated(Fore.GREEN + f"AI Assistant:\n\n{assistant_msg.content}\n\n")
    if "<CAMEL_TASK_DONE>" in user_msg.content:
        break
# Out:
# Original task prompt:
# Design a custom game using pygame
#
# Specified task prompt:
# Design a sci-fi themed 2D platformer game using pygame, including at least 3 unique enemies, 3 levels with varied backgrounds, and a boss battle. Implement special abilities for the player character and design bonus features for players who collect hidden objects throughout the levels.
#
# AI User:
#
# Instruction: Create a player character sprite for the game.
# Input: None.
#
# AI Assistant:
#
# Solution: To create a player character sprite for the game, I will first create a new image with the desired dimensions and design the character using a graphics software like Adobe Photoshop or GIMP. Then, I will save the image as a PNG file with a transparent background. Finally, I will load the image using Pygame's `image.load()` function and create a sprite object with the image as its surface.
#
# Example code:
#
# ```
# player_image = pygame.image.load('player.png').convert_alpha()
# player_sprite = pygame.sprite.Sprite()
# player_sprite.image = player_image
# player_sprite.rect = player_image.get_rect()
# ```
#
# Next request.
#
# AI User:
#
# Instruction: Create three unique enemy sprites for the game.
# Input: None.
#
# AI Assistant:
#
# Solution: To create three unique enemy sprites for the game, I will first design each enemy using a graphics software like Adobe Photoshop or GIMP. Then, I will save each image as a PNG file with a transparent background. Finally, I will load each image using Pygame's `image.load()` function and create a sprite object with the image as its surface.
#
# Example code:
#
# ```
# enemy1_image = pygame.image.load('enemy1.png').convert_alpha()
# enemy1_sprite = pygame.sprite.Sprite()
# enemy1_sprite.image = enemy1_image
# enemy1_sprite.rect = enemy1_image.get_rect()
#
# enemy2_image = pygame.image.load('enemy2.png').convert_alpha()
# enemy2_sprite = pygame.sprite.Sprite()
# enemy2_sprite.image = enemy2_image
# enemy2_sprite.rect = enemy2_image.get_rect()
#
# enemy3_image = pygame.image.load('enemy3.png').convert_alpha()
# enemy3_sprite = pygame.sprite.Sprite()
# enemy3_sprite.image = enemy3_image
# enemy3_sprite.rect = enemy3_image.get_rect()
# ```
#
# Next request.
#
# AI User:
#
# Instruction: Create three levels with varied backgrounds for the game.
# Input: None.
#
# AI Assistant:
#
# Solution: To create three levels with varied backgrounds for the game, I will first create a new Pygame surface with the desired dimensions for each level. Then, I will load the background image for each level using Pygame's `image.load()` function and blit it onto the surface. Finally, I will add any additional level elements such as platforms, enemies, and collectibles.
#
# Example code:
#
# ```
# # Level 1
# level1_surface = pygame.Surface((800, 600))
# level1_background = pygame.image.load('level1_background.png').convert()
# level1_surface.blit(level1_background, (0, 0))
# # Add platforms, enemies, and collectibles to level1_surface
#
# # Level 2
# level2_surface = pygame.Surface((800, 600))
# level2_background = pygame.image.load('level2_background.png').convert()
# level2_surface.blit(level2_background, (0, 0))
# # Add platforms, enemies, and collectibles to level2_surface
#
# # Level 3
# level3_surface = pygame.Surface((800, 600))
# level3_background = pygame.image.load('level3_background.png').convert()
# level3_surface.blit(level3_background, (0, 0))
# # Add platforms, enemies, and collectibles to level3_surface
# ```
#
# Next request.
#
# AI User:
#
# Instruction: Implement a boss battle for the game.
# Input: None.
#
# AI Assistant:
#
# Solution: To implement a boss battle for the game, I will first create a new Pygame surface with the desired dimensions for the boss arena. Then, I will load the boss character sprite using Pygame's `image.load()` function and create a sprite object with the image as its surface. Next, I will add any additional boss elements such as attacks and special abilities. Finally, I will program the boss behavior using Pygame's sprite collision detection and event handling functions.
#
# Example code:
#
# ```
# boss_arena_surface = pygame.Surface((800, 600))
# boss_image = pygame.image.load('boss.png').convert_alpha()
# boss_sprite = pygame.sprite.Sprite()
# boss_sprite.image = boss_image
# boss_sprite.rect = boss_image.get_rect(center=(400, 300))
# # Add boss attacks and special abilities to boss_sprite
#
# # Boss behavior
# while boss_health > 0:
#     for event in pygame.event.get():
#         if event.type == pygame.QUIT:
#             pygame.quit()
#             sys.exit()
#
#     # Handle player attacks on boss_sprite
#     if pygame.sprite.collide_rect(player_sprite, boss_sprite):
#         boss_health -= player_attack_damage
#
#     # Handle boss attacks on player_sprite
#     if pygame.sprite.collide_rect(player_sprite, boss_attack_sprite):
#         player_health -= boss_attack_damage
#
#     # Update game display
#     screen.blit(boss_arena_surface, (0, 0))
#     all_sprites.draw(screen)
#     pygame.display.flip()
#
# # Boss defeated
# # Add victory screen or transition to next level
# ```
#
# Next request.
#
# AI User:
#
# Instruction: Implement a special ability for the player character.
# Input: None.
#
# AI Assistant:
#
# Solution: To implement a special ability for the player character, I will first create a new Pygame surface with the desired dimensions for the ability icon. Then, I will load the ability icon image using Pygame's `image.load()` function and blit it onto the surface. Next, I will program the ability behavior using Pygame's sprite collision detection and event handling functions.
#
# Example code:
#
# ```
# ability_icon_surface = pygame.Surface((50, 50))
# ability_icon_image = pygame.image.load('ability_icon.png').convert_alpha()
# ability_icon_surface.blit(ability_icon_image, (0, 0))
#
# # Ability behavior
# while using_ability:
#     for event in pygame.event.get():
#         if event.type == pygame.QUIT:
#             pygame.quit()
#             sys.exit()
#
#     # Handle player input to activate ability
#     if event.type == pygame.KEYDOWN and event.key == pygame.K_SPACE:
#         player_ability()
#
#     # Update game display
#     screen.blit(game_surface, (0, 0))
#     all_sprites.draw(screen)
#     screen.blit(ability_icon_surface, (10, 10))
#     pygame.display.flip()
#
# # Player ability deactivated
# ```
#
# Next request.
#
# AI User:
#
# Instruction: Design bonus features for players who collect hidden objects throughout the levels.
# Input: None.
#
# AI Assistant:
#
# Solution: To design bonus features for players who collect hidden objects throughout the levels, I will first create a new Pygame surface with the desired dimensions for the bonus screen. Then, I will program the bonus behavior using Pygame's sprite collision detection and event handling functions.
#
# Example code:
#
# ```
# # Bonus screen
# bonus_surface = pygame.Surface((800, 600))
# bonus_font = pygame.font.Font(None, 36)
# bonus_text = bonus_font.render('Congratulations! You found all the hidden objects!', True, (255, 255, 255))
# bonus_surface.blit(bonus_text, (200, 200))
# # Add bonus rewards such as extra lives or power-ups to bonus_surface
#
# # Bonus behavior
# if all_hidden_objects_collected:
#     while True:
#         for event in pygame.event.get():
#             if event.type == pygame.QUIT:
#                 pygame.quit()
#                 sys.exit()
#
#         # Handle player input to exit bonus screen
#         if event.type == pygame.KEYDOWN and event.key == pygame.K_SPACE:
#             break
#
#         # Update game display
#         screen.blit(bonus_surface, (0, 0))
#         pygame.display.flip()
# ```
#
# Next request.
#
# AI User:
#
# Instruction: Add background music and sound effects to the game.
# Input: None.
#
# AI Assistant:
#
# Solution: To add background music and sound effects to the game, I will first load the audio files using Pygame's `mixer.music.load()` and `mixer.Sound()` functions. Then, I will play the background music using Pygame's `mixer.music.play()` function and add sound effects to the game using Pygame's `Sound.play()` function.
#
# Example code:
#
# ```
# # Load audio files
# pygame.mixer.music.load('background_music.mp3')
# jump_sound = pygame.mixer.Sound('jump_sound.wav')
# collectible_sound = pygame.mixer.Sound('collectible_sound.wav')
# enemy_hit_sound = pygame.mixer.Sound('enemy_hit_sound.wav')
#
# # Play background music
# pygame.mixer.music.play(-1)
#
# # Add sound effects to game
# if player_jumps:
#     jump_sound.play()
#
# if collectible_collected:
#     collectible_sound.play()
#
# if enemy_hit:
#     enemy_hit_sound.play()
# ```
#
# Next request.
#
# AI User:
#
# Instruction: Add a scoring system to the game.
# Input: None.
#
# AI Assistant:
#
# Solution: To add a scoring system to the game, I will first create a variable to store the player's score and initialize it to 0. Then, I will program the game to increment the score when the player collects a collectible or defeats an enemy. Finally, I will display the score on the game screen using Pygame's `font.render()` and `blit()` functions.
#
# Example code:
#
# ```
# # Initialize score
# score = 0
#
# # Increment score when player collects collectible or defeats enemy
# if collectible_collected:
#     score += 10
#
# if enemy_defeated:
#     score += 50
#
# # Display score on game screen
# score_font = pygame.font.Font(None, 36)
# score_text = score_font.render('Score: ' + str(score), True, (255, 255, 255))
# screen.blit(score_text, (10, 10))
# ```
#
# Next request.
#
# AI User:
#
# Instruction: Add a game over screen and option to restart the game.
# Input: None.
#
# AI Assistant:
#
# Solution: To add a game over screen and option to restart the game, I will first create a new Pygame surface with the desired dimensions for the game over screen. Then, I will program the game over behavior using Pygame's sprite collision detection and event handling functions. Finally, I will add a restart option that resets the game variables and returns the player to the starting level.
#
# Example code:
#
# ```
# # Game over screen
# game_over_surface = pygame.Surface((800, 600))
# game_over_font = pygame.font.Font(None, 72)
# game_over_text = game_over_font.render('Game Over', True, (255, 0, 0))
# game_over_surface.blit(game_over_text, (200, 200))
#
# # Game over behavior
# while game_over:
#     for event in pygame.event.get():
#         if event.type == pygame.QUIT:
#             pygame.quit()
#             sys.exit()
#
#     # Handle player input to restart game
#     if event.type == pygame.KEYDOWN and event.key == pygame.K_SPACE:
#         # Reset game variables
#         score = 0
#         player_health = 100
#         # Return player to starting level
#         current_level = 1
#         # Reset player and enemy positions
#         player_sprite.rect.x = 0
#         player_sprite.rect.y = 0
#         enemy1_sprite.rect.x = 100
#         enemy1_sprite.rect.y = 100
#         enemy2_sprite.rect.x = 200
#         enemy2_sprite.rect.y = 200
#         enemy3_sprite.rect.x = 300
#         enemy3_sprite.rect.y = 300
#         # Reset game over flag
#         game_over = False
#
#     # Update game display
#     screen.blit(game_over_surface, (0, 0))
#     pygame.display.flip()
# ```
#
# Next request.
#
# AI User:
#
# Instruction: Add a main menu screen with options to start a new game, continue a saved game, or quit the game.
# Input: None.
#
# AI Assistant:
#
# Solution: To add a main menu screen with options to start a new game, continue a saved game, or quit the game, I will first create a new Pygame surface with the desired dimensions for the main menu screen. Then, I will program the main menu behavior using Pygame's sprite collision detection and event handling functions. Finally, I will add options to start a new game, continue a saved game, or quit the game.
#
# Example code:
#
# ```
# # Main menu screen
# menu_surface = pygame.Surface((800, 600))
# menu_font = pygame.font.Font(None, 72)
# menu_text = menu_font.render('Main Menu', True, (255, 255, 255))
# menu_surface.blit(menu_text, (200, 200))
#
# # Main menu behavior
# while True:
#     for event in pygame.event.get():
#         if event.type == pygame.QUIT:
#             pygame.quit()
#             sys.exit()
#
#     # Handle player input to start new game
#     if event.type == pygame.KEYDOWN and event.key == pygame.K_n:
#         # Reset game variables
#         score = 0
#         player_health = 100
#         # Return player to starting level
#         current_level = 1
#         # Reset player and enemy positions
#         player_sprite.rect.x = 0
#         player_sprite.rect.y = 0
#         enemy1_sprite.rect.x = 100
#         enemy1_sprite.rect.y = 100
#         enemy2_sprite.rect.x = 200
#         enemy2_sprite.rect.y = 200
#         enemy3_sprite.rect.x = 300
#         enemy3_sprite.rect.y = 300
#         # Start new game
#         game_loop()
#
#     # Handle player input to continue saved game
#     if event.type == pygame.KEYDOWN and event.key == pygame.K_c:
#         # Load saved game variables
#         score = load_score()
#         player_health = load_health()
#         current_level = load_level()
#         # Load saved player and enemy positions
#         player_sprite.rect.x, player_sprite.rect.y = load_player_position()
#         enemy1_sprite.rect.x, enemy1_sprite.rect.y = load_enemy1_position()
#         enemy2_sprite.rect.x, enemy2_sprite.rect.y = load_enemy2_position()
#         enemy3_sprite.rect.x, enemy3_sprite.rect.y = load_enemy3_position()
#         # Continue saved game
#         game_loop()
#
#     # Handle player input to quit game
#     if event.type == pygame.KEYDOWN and event.key == pygame.K_q:
#         pygame.quit()
#         sys.exit()
#
#     # Update game display
#     screen.blit(menu_surface, (0, 0))
#     pygame.display.flip()
# ```
#
# Next request.
